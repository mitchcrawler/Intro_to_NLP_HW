# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import sklearn

# %%
# Main NLP Class

from pipeUtils import Document
from pipeUtils import Annotation
import re

class PadClassificationSystem:
    def __init__(self):
        #initiate necessary components        
        self.target_rules=self.getTargetRegexes()        
        self.negation_rules = self.getNegRegexes()
                
    def process(self, document):
        document_id = document.document_id
        ann_index=0
        for reg in self.target_rules:
            for match in reg.finditer(document.text):
                ann_id = 'NLP_'+ str(document_id) + '_' + str(ann_index)
                ann_index=ann_index+1
                new_annotation = Annotation(start_index=int(match.start()), 
                                    end_index=int(match.end()), 
                                    type='pad_annotation',
                                    ann_id = ann_id
                                    )
                new_annotation.spanned_text = document.text[new_annotation.start_index:new_annotation.end_index]

                # Check negation right before the found target up to 30 charachers before, 
                # making sure that the pre-text does not cross the text boundary and is valid

                if new_annotation.start_index - 30 > 0:
                    pre_text_start = new_annotation.start_index - 30
                else:
                    pre_text_start = 0

                # ending index of the pre_text is the beginning of the found target    
                pre_text_end = new_annotation.start_index    

                # substring the document text to identify the pre_text string
                pre_text = doc.text[pre_text_start: pre_text_end]

                # We do not need to know the exact location of the negation keyword, so re.search is acceptable
                for neg_regex in self.negation_rules:
                    if re.search(neg_regex, pre_text):
                        new_annotation.attributes["Negation"] ="Negated"

                document.annotations.append(new_annotation)
        
        return document 
    
    def getTargetRegexes(self):
        target_regexes = []
        regexes = [
            r'\bp(eri\w+)?\s*(a(rt\w+)?|v(as\w+)?)\s*d(ise\w+)?\b',
            r'\bhistory\s*(?:\w+\W+){1,5}?p(eri\w+)?\s*(a(rt\w+)?|v(as\w+)?)\s*d(ise\w+)?\b',
            r'\bpvd\b',
            r'\bhas\s*(?:\w+\W+){1,5}?p(eri\w+)?\s*(a(rt\w+)?|v(as\w+)?)\s*d(ise\w+)?\b',
            r'\bsug(es\w+)\s*(?:\w+\W+){1,5}?p(eri\w+)?\s*(a(rt\w+)?|v(as\w+)?)\s*d(ise\w+)?\b',
            r'\bdiagnosis\s*(?:\w+\W+){1,5}?p(eri\w+)?\s*(a(rt\w+)?|v(as\w+)?)\s*d(ise\w+)?\b',
            r'\ba(nk\w+)?(\s*\-|\\|\/)?\s*b(ra\w+)?\s*i(nd\w+)?\b((\W*)?(?:\w+\W+){1,5}?(0*(\.\d{1,2}))|(1*(\.[4-9])))+'
            
        ]
        for reg in regexes:
            target_regexes.append(re.compile(reg, re.IGNORECASE))
        return target_regexes

    def getNegRegexes(self):
        target_regexes = []
        regexes = [
            r'\bno\b',
            r'no\s*evidence\s*of'  ,
            r'does\s*not\s*have',
            r'denies',
            r'^(?!.*(\bp(eri\w+)?\s*(a(rt\w+)?|v(as\w+)?)\s*d(ise\w+)?\b)).*$',
            r'^(?!.*(\ba(nk\w+)?(\s*\-|\\|\/)?\s*b(ra\w+)?\s*i(nd\w+)?\b)).*$'
        ]
        for reg in regexes:
            target_regexes.append(re.compile(reg, re.IGNORECASE))
        return target_regexes

# %%
#  test case
nlp_system = PadClassificationSystem()
doc_text = '''
Patient has peripheral artery disease. ---------- \nPatient also has PVD or peripheral vascular\ndisease or pvd . 
\n The patient does not have any peripheral artery disease 
but has peripheral arterial disease . The patient denies having peripheral vascular disease . \n 
The patient has a femoral and illiac occlusion which is suggestive of peripheral arterial disease.\nthis is just some random text, has no meaning at all
'''
doc=Document(text=doc_text, document_id='Doc1')
 
out_doc=nlp_system.process(doc)
print(out_doc.toString())
# Out:
# Doc1
# -------
#
# Patient has peripheral artery disease. ----------
# Patient also has PVD or peripheral vascular
# disease or pvd .
#
#  The patient does not have any peripheral artery disease
# but has peripheral arterial disease . The patient denies having peripheral vascular disease .
#
# The patient has a femoral and illiac occlusion which is suggestive of peripheral arterial disease.
# this is just some random text, has no meaning at all
#
# -------
# NLP_Doc1_0 pad_annotation 13 38 peripheral artery disease
# NLP_Doc1_1 pad_annotation 69 72 PVD
# NLP_Doc1_2 pad_annotation 76 103 peripheral vascular
# disease
# NLP_Doc1_3 pad_annotation 107 110 pvd
# NLP_Doc1_4 pad_annotation 146 171 peripheral artery disease [Negation:Negated]
# NLP_Doc1_5 pad_annotation 181 208 peripheral arterial disease
# NLP_Doc1_6 pad_annotation 237 264 peripheral vascular disease [Negation:Negated]
# NLP_Doc1_7 pad_annotation 340 367 peripheral arterial disease [Negation:Negated]
# NLP_Doc1_8 pad_annotation 69 72 PVD
# NLP_Doc1_9 pad_annotation 107 110 pvd
# NLP_Doc1_10 pad_annotation 65 103 has PVD or peripheral vascular
# disease

# %%
from pipeUtils import Annotation
from pipeUtils import Document
 
import os
import glob

# %%
# Read all test documents
unid="u1166466"
project_1 = "PAD_TRAIN"
project_2 = "PAD_ABI"
path_1 = "/home/"+str(unid)+"/BRAT/"+str(unid)+"/"+project_1
path_2 = "/home/"+str(unid)+"/BRAT/"+str(unid)+"/"+project_2

# %%
test_docs=dict()
test_doc_paths = glob.glob(str(path_1+'/*.txt')) 
for d in test_doc_paths:
    doc = Document()
    #print(d)
    doc.load_document_from_file(d)
    #print(str(d[:-3])+'ann')
    doc.load_annotations_from_brat(str(d[:-3])+'ann')
    #print(os.path.basename(d))
    test_docs[os.path.basename(d)]=doc


test_docs
# Out:
# {'18600_2.txt': <pipeUtils.Document at 0x7fedb01d7da0>,
#  '21223_3.txt': <pipeUtils.Document at 0x7fedb01a0208>,
#  '25879_4.txt': <pipeUtils.Document at 0x7fedb01d7898>,
#  '25879_5.txt': <pipeUtils.Document at 0x7fee26cd62e8>,
#  '37_10.txt': <pipeUtils.Document at 0x7fedb01d77b8>,
#  '37_11.txt': <pipeUtils.Document at 0x7fedb01ab240>,
#  '37_12.txt': <pipeUtils.Document at 0x7fedb01e1278>,
#  '37_13.txt': <pipeUtils.Document at 0x7fedb01a5390>,
#  '37_14.txt': <pipeUtils.Document at 0x7fedb0199e80>,
#  '37_15.txt': <pipeUtils.Document at 0x7fedb01a0048>,
#  '37_16.txt': <pipeUtils.Document at 0x7fedb01d7908>,
#  '37_17.txt': <pipeUtils.Document at 0x7fedb01ab390>,
#  '37_18.txt': <pipeUtils.Document at 0x7fedb01abb70>,
#  '37_19.txt': <pipeUtils.Document at 0x7fedb01abac8>,
#  '56_0.txt': <pipeUtils.Document at 0x7fedb01d7c50>,
#  '56_1.txt': <pipeUtils.Document at 0x7fedb01a56d8>,
#  '56_2.txt': <pipeUtils.Document at 0x7fedb01990b8>,
#  '56_3.txt': <pipeUtils.Document at 0x7fedb01abf28>,
#  '56_4.txt': <pipeUtils.Document at 0x7fedb01d79e8>,
#  '56_5.txt': <pipeUtils.Document at 0x7fedb01abd68>,
#  '56_6.txt': <pipeUtils.Document at 0x7fedb01a5550>,
#  '56_7.txt': <pipeUtils.Document at 0x7fedb01a55f8>,
#  '56_8.txt': <pipeUtils.Document at 0x7fedb01ab9e8>,
#  '56_9.txt': <pipeUtils.Document at 0x7fedb01aba90>,
#  '6677_0.txt': <pipeUtils.Document at 0x7fedb01abc88>,
#  '6677_1.txt': <pipeUtils.Document at 0x7fedb01ab0b8>}

# %%
# Processing the all notes
nlp_system = PadClassificationSystem()

for doc_id in  test_docs.keys():
    nlp_system.process(test_docs.get(doc_id))
    print(test_docs.get(doc_id))
# Out:
# <pipeUtils.Document object at 0x7fedb01ab0b8>
# <pipeUtils.Document object at 0x7fedb01abb70>
# <pipeUtils.Document object at 0x7fedb01abac8>
# <pipeUtils.Document object at 0x7fedb01abf28>
# <pipeUtils.Document object at 0x7fedb01abc88>
# <pipeUtils.Document object at 0x7fedb01ab240>
# <pipeUtils.Document object at 0x7fedb01aba90>
# <pipeUtils.Document object at 0x7fedb01abd68>
# <pipeUtils.Document object at 0x7fedb01ab390>
# <pipeUtils.Document object at 0x7fedb01ab9e8>
# <pipeUtils.Document object at 0x7fedb01e1278>
# <pipeUtils.Document object at 0x7fedb01d7c50>
# <pipeUtils.Document object at 0x7fedb01d7da0>
# <pipeUtils.Document object at 0x7fedb01d77b8>
# <pipeUtils.Document object at 0x7fedb01d7908>
# <pipeUtils.Document object at 0x7fedb01d7898>
# <pipeUtils.Document object at 0x7fedb01d79e8>
# <pipeUtils.Document object at 0x7fee26cd62e8>
# <pipeUtils.Document object at 0x7fedb01a55f8>
# <pipeUtils.Document object at 0x7fedb01a5550>
# <pipeUtils.Document object at 0x7fedb01a56d8>
# <pipeUtils.Document object at 0x7fedb01a5390>
# <pipeUtils.Document object at 0x7fedb01a0208>
# <pipeUtils.Document object at 0x7fedb01a0048>
# <pipeUtils.Document object at 0x7fedb01990b8>
# <pipeUtils.Document object at 0x7fedb0199e80>

# %%
tp_total = 0
fp_total = 0
fn_total = 0
tp_list_total = []
fp_list_total= []
fn_list_total = []
for doc_id in test_docs.keys():
    tp, fp, fn, tp_list, fp_list, fn_list = (test_docs.get(doc_id)).compare_types_by_span('Peripheral_arterial_disease','pad_annotation', True)
    tp_total = tp_total + tp
    fp_total = fp_total + fp
    fn_total = fn_total + fn
    tp_list_total.extend(tp_list)
    fp_list_total.extend(fp_list)
    fn_list_total.extend(fn_list)

print('TP =',tp_total, 'FP =',fp_total, 'FN =',fn_total)

if tp_total > 0 :
    precision = tp_total / (tp_total + fp_total)
    print('Precision=',round(precision,3))

if tp_total > 0 :
    recall = tp_total / (tp_total + fn_total)
    print('Recall=',round(recall,3))

for a in tp_list_total:
    print(a[0].toString(),'||', a[1].toString())
for a in fp_list_total:
    print(a.toString())
for a in fn_list_total:
    print(a.toString())
# Out:
# TP = 10 FP = 5 FN = 12
# Precision= 0.667
# Recall= 0.455
# NLP_6677_1.txt_0 pad_annotation 207 210 PVD [Negation:Negated] || T4 Peripheral_arterial_disease 207 210 PVD
# NLP_6677_1.txt_1 pad_annotation 3156 3159 PVD [Negation:Negated] || T3 Peripheral_arterial_disease 3156 3159 PVD [Affirmed:Affirmed]
# NLP_6677_1.txt_2 pad_annotation 207 210 PVD [Negation:Negated] || T4 Peripheral_arterial_disease 207 210 PVD
# NLP_6677_1.txt_3 pad_annotation 3156 3159 PVD [Negation:Negated] || T3 Peripheral_arterial_disease 3156 3159 PVD [Affirmed:Affirmed]
# NLP_6677_0.txt_0 pad_annotation 207 210 PVD [Negation:Negated] || T1 Peripheral_arterial_disease 207 210 PVD
# NLP_6677_0.txt_1 pad_annotation 3156 3159 PVD [Negation:Negated] || T2 Peripheral_arterial_disease 3156 3159 PVD
# NLP_6677_0.txt_2 pad_annotation 207 210 PVD [Negation:Negated] || T1 Peripheral_arterial_disease 207 210 PVD
# NLP_6677_0.txt_3 pad_annotation 3156 3159 PVD [Negation:Negated] || T2 Peripheral_arterial_disease 3156 3159 PVD
# NLP_18600_2.txt_0 pad_annotation 419 422 pvd  || T2 Peripheral_arterial_disease 419 422 pvd [Affirmed:Affirmed]
# NLP_18600_2.txt_1 pad_annotation 419 422 pvd  || T2 Peripheral_arterial_disease 419 422 pvd [Affirmed:Affirmed]
# NLP_6677_1.txt_4 pad_annotation 2609 2642 ankle brachial index of
#      0.57 [Negation:Negated]
# NLP_6677_0.txt_4 pad_annotation 2609 2642 ankle brachial index of
#      0.57 [Negation:Negated]
# NLP_25879_4.txt_0 pad_annotation 1419 1447 ankle brachial index is 0.71
# NLP_25879_5.txt_0 pad_annotation 1419 1447 ankle brachial index is 0.71
# NLP_21223_3.txt_0 pad_annotation 1755 1784 ankle-brachial index was 0.36
# T2 Peripheral_arterial_disease 433 436 chf [Affirmed:Hypthetical]
# T1 Peripheral_arterial_disease 155 161 Reason [Affirmed:Negation]
# T3 Peripheral_arterial_disease 167 228 chf [Affirmed:Hypthetical]
# T2 Peripheral_arterial_disease 435 438 chf [Affirmed:Hypthetical]
# T1 Peripheral_arterial_disease 405 411 REASON [Affirmed:Negation]
# T3 Peripheral_arterial_disease 453 456 CHF [Affirmed:Hypthetical]
# T2 Peripheral_arterial_disease 4088 4091 CHF [Affirmed:Hypthetical]
# T2 Peripheral_arterial_disease 434 437 chf [Affirmed:Hypthetical]
# T1 Peripheral_arterial_disease 229 238 Admitting [Affirmed:Hypthetical]
# T2 Peripheral_arterial_disease 441 444 CHF [Affirmed:Hypthetical]
# T2 Peripheral_arterial_disease 441 444 CHF [Affirmed:Hypthetical]
# T3 Peripheral_arterial_disease 714 726 h/o diabetes [Affirmed:Hypthetical]

# %%
tp_total = 0
fp_total = 0
fn_total = 0
tp_list_total = []
fp_list_total= []
fn_list_total = []
attributes_to_compare=[]
# To compare attributes, create a list of tuples for each pair to compare:
# attributes_to_compare.append[(A1_type, A1_att_name, A1_att_value),(A2_type, A2_att_name, A2_att_value)]
attributes_to_compare.append([('Peripheral_arterial_disease', 'Negation', 'Negated','Hypthetical'),('pad_annotation', 'Negation', 'Negated')])

for doc_id in test_docs.keys():
    tp, fp, fn, tp_list, fp_list, fn_list = (test_docs.get(doc_id)).\
    compare_types_by_span_and_attributes('Peripheral_arterial_disease','pad_annotation', attributes_to_compare , False)
    tp_total = tp_total + tp
    fp_total = fp_total + fp
    fn_total = fn_total + fn
    tp_list_total.extend(tp_list)
    fp_list_total.extend(fp_list)
    fn_list_total.extend(fn_list)

print('TP =',tp_total, 'FP =',fp_total, 'FN =',fn_total)

if tp_total > 0 :
    precision = tp_total / (tp_total + fp_total)
    print('Precision=',round(precision,3))

if tp_total > 0 :
    recall = tp_total / (tp_total + fn_total)
    print('Recall=',round(recall,3))

#for a in tp_list_total:
#    print(a[0].toString(),'||', a[1].toString())
for a in fp_list_total:
    print(a.toString())
for a in fn_list_total:
    print(a.toString())
# Out:
# TP = 2 FP = 13 FN = 16
# Precision= 0.133
# Recall= 0.111
# NLP_6677_1.txt_0 pad_annotation 207 210 PVD [Negation:Negated]
# NLP_6677_1.txt_1 pad_annotation 3156 3159 PVD [Negation:Negated]
# NLP_6677_1.txt_2 pad_annotation 207 210 PVD [Negation:Negated]
# NLP_6677_1.txt_3 pad_annotation 3156 3159 PVD [Negation:Negated]
# NLP_6677_1.txt_4 pad_annotation 2609 2642 ankle brachial index of
#      0.57 [Negation:Negated]
# NLP_6677_0.txt_0 pad_annotation 207 210 PVD [Negation:Negated]
# NLP_6677_0.txt_1 pad_annotation 3156 3159 PVD [Negation:Negated]
# NLP_6677_0.txt_2 pad_annotation 207 210 PVD [Negation:Negated]
# NLP_6677_0.txt_3 pad_annotation 3156 3159 PVD [Negation:Negated]
# NLP_6677_0.txt_4 pad_annotation 2609 2642 ankle brachial index of
#      0.57 [Negation:Negated]
# NLP_25879_4.txt_0 pad_annotation 1419 1447 ankle brachial index is 0.71
# NLP_25879_5.txt_0 pad_annotation 1419 1447 ankle brachial index is 0.71
# NLP_21223_3.txt_0 pad_annotation 1755 1784 ankle-brachial index was 0.36
# T3 Peripheral_arterial_disease 3156 3159 PVD [Affirmed:Affirmed]
# T4 Peripheral_arterial_disease 207 210 PVD
# T2 Peripheral_arterial_disease 433 436 chf [Affirmed:Hypthetical]
# T1 Peripheral_arterial_disease 207 210 PVD
# T2 Peripheral_arterial_disease 3156 3159 PVD
# T1 Peripheral_arterial_disease 155 161 Reason [Affirmed:Negation]
# T3 Peripheral_arterial_disease 167 228 chf [Affirmed:Hypthetical]
# T2 Peripheral_arterial_disease 435 438 chf [Affirmed:Hypthetical]
# T1 Peripheral_arterial_disease 405 411 REASON [Affirmed:Negation]
# T3 Peripheral_arterial_disease 453 456 CHF [Affirmed:Hypthetical]
# T2 Peripheral_arterial_disease 4088 4091 CHF [Affirmed:Hypthetical]
# T2 Peripheral_arterial_disease 434 437 chf [Affirmed:Hypthetical]
# T1 Peripheral_arterial_disease 229 238 Admitting [Affirmed:Hypthetical]
# T2 Peripheral_arterial_disease 441 444 CHF [Affirmed:Hypthetical]
# T2 Peripheral_arterial_disease 441 444 CHF [Affirmed:Hypthetical]
# T3 Peripheral_arterial_disease 714 726 h/o diabetes [Affirmed:Hypthetical]

# %%
import pymysql
import pandas as pd
import getpass
import re

conn = pymysql.connect(host="mysql",
                       port=3306,user="jovyan",
                       passwd=getpass.getpass("Enter MySQL passwd for jovyan"),db='mimic2')
cursor = conn.cursor()
# Out:
# Enter MySQL passwd for jovyan········

# %%
pad_data = pd.read_sql("""SELECT subject_id, 
                      category, 
                      text FROM noteevents limit 100000 """,conn)

# %%
final_nlp_system = PadClassificationSystem()

# %%
output = []
counter = 0
for index , row in pad_data.sample(10000).iterrows():    
    doc = Document(document_id=str(row.subject_id) + '_' + str(index), text=row.text)
    final_nlp_system.process(doc)
    if(len(doc.annotations) > 0):
        i = 1
        for a in doc.annotations:
            if( a.type == 'pad_annotation'):
                neg_flag = 0
                # Switch the flag to 1 when the mention is negated
                if('definite_negated_existence' in a.attributes):
                    neg_flag=1
                ### Each row in the dictionary
                record_id  = str(row.subject_id) + '_' + str(index)+'_'+str(i)
                subject_id =  row.subject_id
                note_id = str(row.subject_id) + '_' + str(index)
                annotation_type = a.type
                snippet = doc.text[int(a.start_index): int(a.end_index)]
                out_list = [record_id, subject_id, note_id, annotation_type, \
                            a.start_index, a.end_index, \
                            snippet, neg_flag]
                output.append(out_list)
                i=i+1
                counter=counter+1
                # Print . after 10 identified records
                if counter%10 == 0:
                    print('.', end='')
        else:
            continue
        break
# Out:
# ...................................

# %%
columns=['record_id','subject_id', 'note_id', 'annotation_type', 'span_start', 'span_end', 'PAD_snippet', 'neg_flag']
result_data_frame = (pd.DataFrame(output, columns=columns))

result_data_frame.describe()
result_data_frame
# Out:
#          record_id  subject_id      note_id annotation_type  span_start  \
# 0    12457_75109_1       12457  12457_75109  pad_annotation         381
# 1    10811_64680_1       10811  10811_64680  pad_annotation        1592
# 2     4001_26574_1        4001   4001_26574  pad_annotation         252
# 3     4422_28411_1        4422   4422_28411  pad_annotation         752
# 4     6809_41174_1        6809   6809_41174  pad_annotation         988
# 5    15847_94764_1       15847  15847_94764  pad_annotation         251
# 6    15847_94764_2       15847  15847_94764  pad_annotation        2597
# 7    15847_94764_3       15847  15847_94764  pad_annotation        2906
# 8       353_2032_1         353     353_2032  pad_annotation        1077
# 9       353_2032_2         353     353_2032  pad_annotation        1077
# 10    2788_18713_1        2788   2788_18713  pad_annotation        1456
# 11    7251_43197_1        7251   7251_43197  pad_annotation         377
# 12   13552_81798_1       13552  13552_81798  pad_annotation         953
# 13   11080_65694_1       11080  11080_65694  pad_annotation         438
# 14   11080_65694_2       11080  11080_65694  pad_annotation         454
# 15   11080_65694_3       11080  11080_65694  pad_annotation         512
# 16   11080_65694_4       11080  11080_65694  pad_annotation         816
# 17    1822_12904_1        1822   1822_12904  pad_annotation        1081
# 18    6470_38901_1        6470   6470_38901  pad_annotation         804
# 19    6470_38901_2        6470   6470_38901  pad_annotation         804
# 20   16326_97296_1       16326  16326_97296  pad_annotation         429
# 21   16326_97296_2       16326  16326_97296  pad_annotation         429
# 22   12413_74698_1       12413  12413_74698  pad_annotation         650
# 23   12413_74698_2       12413  12413_74698  pad_annotation        2307
# 24   12944_78440_1       12944  12944_78440  pad_annotation         679
# 25   12944_78440_2       12944  12944_78440  pad_annotation         679
# 26    7638_45966_1        7638   7638_45966  pad_annotation        1678
# 27    7638_45966_2        7638   7638_45966  pad_annotation        1678
# 28    7251_43299_1        7251   7251_43299  pad_annotation         581
# 29       149_307_1         149      149_307  pad_annotation        1620
# ..             ...         ...          ...             ...         ...
# 327     433_2666_1         433     433_2666  pad_annotation         460
# 328     433_2666_2         433     433_2666  pad_annotation         460
# 329  10616_63662_1       10616  10616_63662  pad_annotation         500
# 330  10616_63662_2       10616  10616_63662  pad_annotation         500
# 331   6594_39938_1        6594   6594_39938  pad_annotation        3255
# 332     977_6863_1         977     977_6863  pad_annotation         196
# 333   1394_10096_1        1394   1394_10096  pad_annotation         829
# 334  10811_64732_1       10811  10811_64732  pad_annotation         412
# 335   4976_31076_1        4976   4976_31076  pad_annotation         633
# 336  13384_80809_1       13384  13384_80809  pad_annotation         337
# 337  13384_80809_2       13384  13384_80809  pad_annotation         337
# 338   9473_56706_1        9473   9473_56706  pad_annotation         393
# 339   9473_56706_2        9473   9473_56706  pad_annotation        1961
# 340  15107_90060_1       15107  15107_90060  pad_annotation         532
# 341  15107_90060_2       15107  15107_90060  pad_annotation         532
# 342  16326_97287_1       16326  16326_97287  pad_annotation         407
# 343  16326_97287_2       16326  16326_97287  pad_annotation         407
# 344   2512_17360_1        2512   2512_17360  pad_annotation         311
# 345   2512_17360_2        2512   2512_17360  pad_annotation         311
# 346     353_2037_1         353     353_2037  pad_annotation         749
# 347     353_2037_2         353     353_2037  pad_annotation         749
# 348  12573_75326_1       12573  12573_75326  pad_annotation         188
# 349  15892_94476_1       15892  15892_94476  pad_annotation         167
# 350  13078_80062_1       13078  13078_80062  pad_annotation         965
# 351   1905_13205_1        1905   1905_13205  pad_annotation         311
# 352   1905_13205_2        1905   1905_13205  pad_annotation        3660
# 353   1905_13205_3        1905   1905_13205  pad_annotation        6532
# 354   1905_13205_4        1905   1905_13205  pad_annotation        3639
# 355  11433_68699_1       11433  11433_68699  pad_annotation         360
# 356  11433_68699_2       11433  11433_68699  pad_annotation         360
#
#      span_end                                        PAD_snippet  neg_flag
# 0         384                                                pad         0
# 1        1604                                       participated         0
# 2         255                                                PAD         0
# 3         755                                                PAD         0
# 4        1040  ABI on the right is 0.55\n     and on the left...         0
# 5         254                                                PAD         0
# 6        2600                                                PAD         0
# 7        2909                                                PAD         0
# 8        1080                                                PVD         0
# 9        1080                                                PVD         0
# 10       1459                                                PAD         0
# 11        380                                                pad         0
# 12        956                                                pad         0
# 13        441                                                PAD         0
# 14        457                                                PAD         0
# 15        515                                                PAD         0
# 16        819                                                PAD         0
# 17       1114                 ankle brachial\n     index is 0.64         0
# 18        807                                                PVD         0
# 19        807                                                PVD         0
# 20        432                                                PVD         0
# 21        432                                                PVD         0
# 22        653                                                PAD         0
# 23       2310                                                PAD         0
# 24        682                                                PVD         0
# 25        682                                                PVD         0
# 26       1681                                                PVD         0
# 27       1681                                                PVD         0
# 28        584                                                PAD         0
# 29       1623                                                pad         0
# ..        ...                                                ...       ...
# 327       463                                                PVD         0
# 328       463                                                PVD         0
# 329       503                                                PVD         0
# 330       503                                                PVD         0
# 331      3258                                                pad         0
# 332       199                                                pad         0
# 333       832                                                PAD         0
# 334       415                                                PAD         0
# 335       636                                                PAD         0
# 336       340                                                PVD         0
# 337       340                                                PVD         0
# 338       396                                                PAD         0
# 339      1964                                                PAD         0
# 340       535                                                PVD         0
# 341       535                                                PVD         0
# 342       410                                                PVD         0
# 343       410                                                PVD         0
# 344       314                                                PVD         0
# 345       314                                                PVD         0
# 346       752                                                PVD         0
# 347       752                                                PVD         0
# 348       191                                                PAD         0
# 349       170                                                pad         0
# 350       968                                                PAD         0
# 351       338                        peripheral vascular disease         0
# 352      3687                        peripheral vascular disease         0
# 353      6559                        Peripheral vascular disease         0
# 354      3687  history of\ndiabetes, peripheral vascular disease         0
# 355       363                                                PVD         0
# 356       363                                                PVD         0
#
# [357 rows x 8 columns]

# %%
result_data_frame.to_csv('out_table.csv', index=False)
print('Done')
# Out:
# Done
