# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import sklearn

# %%
# Main NLP Class

from pipeUtils import Document
from pipeUtils import Annotation
import re

class PadClassificationSystem:
    def __init__(self):
        #initiate necessary components        
        self.target_rules=self.getTargetRegexes()        
        self.negation_rules = self.getNegRegexes()
                
    def process(self, document):
        document_id = document.document_id
        ann_index=0
        for reg in self.target_rules:
            for match in reg.finditer(document.text):
                ann_id = 'NLP_'+ str(document_id) + '_' + str(ann_index)
                ann_index=ann_index+1
                new_annotation = Annotation(start_index=int(match.start()), 
                                    end_index=int(match.end()), 
                                    type='pad_annotation',
                                    ann_id = ann_id
                                    )
                new_annotation.spanned_text = document.text[new_annotation.start_index:new_annotation.end_index]

                # Check negation right before the found target up to 30 charachers before, 
                # making sure that the pre-text does not cross the text boundary and is valid

                if new_annotation.start_index - 30 > 0:
                    pre_text_start = new_annotation.start_index - 30
                else:
                    pre_text_start = 0

                # ending index of the pre_text is the beginning of the found target    
                pre_text_end = new_annotation.start_index    

                # substring the document text to identify the pre_text string
                pre_text = doc.text[pre_text_start: pre_text_end]

                # We do not need to know the exact location of the negation keyword, so re.search is acceptable
                for neg_regex in self.negation_rules:
                    if re.search(neg_regex, pre_text):
                        new_annotation.attributes["Negation"] ="Negated"

                document.annotations.append(new_annotation)
        
        return document 
    
    def getTargetRegexes(self):
        target_regexes = []
        regexes = [
            r'\bp(eri\w+)?\s*(a(rt\w+)?|v(as\w+)?)\s*d(ise\w+)?\b',
            r'\ba(nk\w+)?(\s*\-|\\|\/)?\s*b(ra\w+)?\s*i(nd\w+)?\b(\W*)?((?:\w+\W+){1,5}?((0*(\.\d{1,2}))|(1*(\.[4-9])))?)?',
            
        ]
        for reg in regexes:
            target_regexes.append(re.compile(reg, re.IGNORECASE))
        return target_regexes

    def getNegRegexes(self):
        target_regexes = []
        regexes = [
            r'/\bno\b',
            r'/no\s*evidence\s*of'  ,
            r'/does\s*not\s*have',
            r'/denies'
        ]
        for reg in regexes:
            target_regexes.append(re.compile(reg, re.IGNORECASE))
        return target_regexes

# %%
#  test case
nlp_system = PadClassificationSystem()
doc_text = '''
Patient has peripheral artery disease. ---------- \nPatient also has PVD or peripheral vascular\ndisease or pvd . 
\n The patient does not have any peripheral artery disease 
but has peripheral arterial disease . The patient denies having peripheral vascular disease . \n 
The patient has a femoral and illiac occlusion which is suggestive of peripheral arterial disease.
'''
doc=Document(text=doc_text, document_id='Doc1')
 
out_doc=nlp_system.process(doc)
print(out_doc.toString())
# Out:
# Doc1
# -------
#
# Patient has peripheral artery disease. ----------
# Patient also has PVD or peripheral vascular
# disease or pvd .
#
#  The patient does not have any peripheral artery disease
# but has peripheral arterial disease . The patient denies having peripheral vascular disease .
#
# The patient has a femoral and illiac occlusion which is suggestive of peripheral arterial disease.
#
# -------
# NLP_Doc1_0 pad_annotation 13 38 peripheral artery disease
# NLP_Doc1_1 pad_annotation 69 72 PVD
# NLP_Doc1_2 pad_annotation 76 103 peripheral vascular
# disease
# NLP_Doc1_3 pad_annotation 107 110 pvd
# NLP_Doc1_4 pad_annotation 146 171 peripheral artery disease
# NLP_Doc1_5 pad_annotation 181 208 peripheral arterial disease
# NLP_Doc1_6 pad_annotation 237 264 peripheral vascular disease
# NLP_Doc1_7 pad_annotation 340 367 peripheral arterial disease

# %%
from pipeUtils import Annotation
from pipeUtils import Document
 
import os
import glob

# %%
# Read all test documents
unid="u1166466"
project_1 = "PAD_TRAIN"
project_2 = "PAD_ABI"
path_1 = "/home/"+str(unid)+"/BRAT/"+str(unid)+"/"+project_1
path_2 = "/home/"+"u0420717"+"/BRAT/"+str(unid)+"/"+project_2

# %%
test_docs=dict()
test_doc_paths = glob.glob(str(path_2+'/*.txt')) 
for d in test_doc_paths:
    doc = Document()
    #print(d)
    doc.load_document_from_file(d)
    #print(str(d[:-3])+'ann')
    doc.load_annotations_from_brat(str(d[:-3])+'ann')
    #print(os.path.basename(d))
    test_docs[os.path.basename(d)]=doc


test_docs
# Out:
# {'10083_27.txt': <pipeUtils.Document at 0x7fa0f4d1d320>,
#  '10594_28.txt': <pipeUtils.Document at 0x7fa0f4d1ffd0>,
#  '10594_29.txt': <pipeUtils.Document at 0x7fa0f4d95d68>,
#  '12272_30.txt': <pipeUtils.Document at 0x7fa0f4d8beb8>,
#  '12403_31.txt': <pipeUtils.Document at 0x7fa0f4d2ba90>,
#  '12403_32.txt': <pipeUtils.Document at 0x7fa0f4d99390>,
#  '12573_33.txt': <pipeUtils.Document at 0x7fa0f4d1d7b8>,
#  '1266_4.txt': <pipeUtils.Document at 0x7fa0f4d99f60>,
#  '1266_5.txt': <pipeUtils.Document at 0x7fa0f4d31e48>,
#  '1266_6.txt': <pipeUtils.Document at 0x7fa0f4d7a4e0>,
#  '13260_34.txt': <pipeUtils.Document at 0x7fa0f4d8add8>,
#  '13625_35.txt': <pipeUtils.Document at 0x7fa0f4d8bfd0>,
#  '1369_8.txt': <pipeUtils.Document at 0x7fa0f4d7b470>,
#  '1371_7.txt': <pipeUtils.Document at 0x7fa0f4d31860>,
#  '14566_36.txt': <pipeUtils.Document at 0x7fa0f4d1dfd0>,
#  '15011_37.txt': <pipeUtils.Document at 0x7fa0f4d2be80>,
#  '1604_10.txt': <pipeUtils.Document at 0x7fa194288b38>,
#  '1604_9.txt': <pipeUtils.Document at 0x7fa0f4d276d8>,
#  '16993_38.txt': <pipeUtils.Document at 0x7fa0f4d7bc18>,
#  '17411_39.txt': <pipeUtils.Document at 0x7fa0f4d8be10>,
#  '17411_40.txt': <pipeUtils.Document at 0x7fa0f4d1d6d8>,
#  '17758_41.txt': <pipeUtils.Document at 0x7fa0f4d95748>,
#  '17758_42.txt': <pipeUtils.Document at 0x7fa0f4d1fc50>,
#  '1795_11.txt': <pipeUtils.Document at 0x7fa0f4d3d940>,
#  '1822_12.txt': <pipeUtils.Document at 0x7fa0f4d27e48>,
#  '18600_43.txt': <pipeUtils.Document at 0x7fa0f4d99550>,
#  '18839_44.txt': <pipeUtils.Document at 0x7fa0f4d2b6d8>,
#  '18839_45.txt': <pipeUtils.Document at 0x7fa0f4d1fd30>,
#  '18992_46.txt': <pipeUtils.Document at 0x7fa0f4d31828>,
#  '18992_47.txt': <pipeUtils.Document at 0x7fa0f4d36b00>,
#  '19468_48.txt': <pipeUtils.Document at 0x7fa0f4d99898>,
#  '1979_13.txt': <pipeUtils.Document at 0x7fa0f4d8af28>,
#  '20794_49.txt': <pipeUtils.Document at 0x7fa0f4d7afd0>,
#  '21223_50.txt': <pipeUtils.Document at 0x7fa0f4d8bac8>,
#  '21380_51.txt': <pipeUtils.Document at 0x7fa0f4d8bd30>,
#  '21380_52.txt': <pipeUtils.Document at 0x7fa0f4d2bcc0>,
#  '22043_53.txt': <pipeUtils.Document at 0x7fa0f4d3df60>,
#  '22043_54.txt': <pipeUtils.Document at 0x7fa0f4d2bac8>,
#  '22368_55.txt': <pipeUtils.Document at 0x7fa0f4d27da0>,
#  '23097_56.txt': <pipeUtils.Document at 0x7fa0f4d7bcf8>,
#  '23097_57.txt': <pipeUtils.Document at 0x7fa0f4d99ef0>,
#  '23643_58.txt': <pipeUtils.Document at 0x7fa0f4d1de80>,
#  '23643_59.txt': <pipeUtils.Document at 0x7fa0f4d8af60>,
#  '24032_60.txt': <pipeUtils.Document at 0x7fa0f4d27a58>,
#  '24032_61.txt': <pipeUtils.Document at 0x7fa0f4d1dc18>,
#  '2503_14.txt': <pipeUtils.Document at 0x7fa0f4d7b748>,
#  '2503_15.txt': <pipeUtils.Document at 0x7fa0f4d36f28>,
#  '25742_62.txt': <pipeUtils.Document at 0x7fa0f4d31cf8>,
#  '25879_63.txt': <pipeUtils.Document at 0x7fa0f4d95ef0>,
#  '25879_64.txt': <pipeUtils.Document at 0x7fa0f4d31e10>,
#  '26136_65.txt': <pipeUtils.Document at 0x7fa0f4d36e10>,
#  '26479_66.txt': <pipeUtils.Document at 0x7fa0f4d36f98>,
#  '2832_16.txt': <pipeUtils.Document at 0x7fa0f4d1da58>,
#  '353_0.txt': <pipeUtils.Document at 0x7fa0f4d7bd30>,
#  '3757_17.txt': <pipeUtils.Document at 0x7fa0f4d3def0>,
#  '4474_18.txt': <pipeUtils.Document at 0x7fa0f4d8aa90>,
#  '4550_19.txt': <pipeUtils.Document at 0x7fa0f4d27ba8>,
#  '6677_20.txt': <pipeUtils.Document at 0x7fa0f4d27668>,
#  '6677_21.txt': <pipeUtils.Document at 0x7fa0f4d7bbe0>,
#  '6809_22.txt': <pipeUtils.Document at 0x7fa0f4d318d0>,
#  '732_1.txt': <pipeUtils.Document at 0x7fa0f4d8bf98>,
#  '7476_23.txt': <pipeUtils.Document at 0x7fa0f4d7ae48>,
#  '846_2.txt': <pipeUtils.Document at 0x7fa0f4d36cc0>,
#  '846_3.txt': <pipeUtils.Document at 0x7fa0f4d7bac8>,
#  '8992_24.txt': <pipeUtils.Document at 0x7fa0f4d8ab70>,
#  '9082_25.txt': <pipeUtils.Document at 0x7fa0f4d367b8>,
#  '9137_26.txt': <pipeUtils.Document at 0x7fa0f4d3d438>}

# %%
# Processing the all notes
nlp_system = PadClassificationSystem()

for doc_id in  test_docs.keys():
    nlp_system.process(test_docs.get(doc_id))

# %%
tp_total = 0
fp_total = 0
fn_total = 0
tp_list_total = []
fp_list_total= []
fn_list_total = []
for doc_id in test_docs.keys():
    tp, fp, fn, tp_list, fp_list, fn_list = (test_docs.get(doc_id)).compare_types_by_span('PAD','pad_annotation', False)
    tp_total = tp_total + tp
    fp_total = fp_total + fp
    fn_total = fn_total + fn
    tp_list_total.extend(tp_list)
    fp_list_total.extend(fp_list)
    fn_list_total.extend(fn_list)

print('TP =',tp_total, 'FP =',fp_total, 'FN =',fn_total)

if tp_total > 0 :
    precision = tp_total / (tp_total + fp_total)
    print('Precision=',round(precision,3))

if tp_total > 0 :
    recall = tp_total / (tp_total + fn_total)
    print('Recall=',round(recall,3))

for a in tp_list_total:
    print(a[0].toString(),'||', a[1].toString())
for a in fp_list_total:
    print(a.toString())
for a in fn_list_total:
    print(a.toString())
# Out:
# TP = 0 FP = 177 FN = 0
# NLP_17411_39.txt_0 pad_annotation 1073 1101 ankle-brachial index is 0.78
# NLP_17411_39.txt_1 pad_annotation 1501 1529 ankle-brachial index is 0.87
# NLP_1604_10.txt_0 pad_annotation 1142 1170 ankle-brachial indices, and
# NLP_1604_10.txt_1 pad_annotation 1320 1351 ankle-
#      brachial index of .
# NLP_1604_10.txt_2 pad_annotation 1511 1518 ABI of
# NLP_12272_30.txt_0 pad_annotation 176 182 ABI B/
# NLP_12272_30.txt_1 pad_annotation 557 563 ABI B/
# NLP_12272_30.txt_2 pad_annotation 1074 1106 ankle brachial
#      index could
# NLP_12272_30.txt_3 pad_annotation 1412 1440 Ankle brachial index is 0.79
# NLP_13625_35.txt_0 pad_annotation 440 443 PVD
# NLP_13625_35.txt_1 pad_annotation 1007 1031 ankle/brachial index is
# NLP_13625_35.txt_2 pad_annotation 1229 1253 ankle/brachial index is
# NLP_732_1.txt_0 pad_annotation 419 422 PVD
# NLP_732_1.txt_1 pad_annotation 986 1015 ankle-brachial index
#      is
# NLP_21380_51.txt_0 pad_annotation 2116 2143 Peripheral vascular disease
# NLP_21380_51.txt_1 pad_annotation 8924 8951 Peripheral vascular disease
# NLP_21380_51.txt_2 pad_annotation 10287 10314 peripheral vascular
# disease
# NLP_21380_51.txt_3 pad_annotation 9019 9047 ankle brachial indexes
# were
# NLP_21380_51.txt_4 pad_annotation 9222 9246 ankle brachial index on
# NLP_21223_50.txt_0 pad_annotation 1665 1693 ankle-brachial indices were
# NLP_21223_50.txt_1 pad_annotation 1755 1784 ankle-brachial index was 0.36
# NLP_1266_6.txt_0 pad_annotation 1513 1542 ankle-brachial index was 0.52
# NLP_7476_23.txt_0 pad_annotation 352 355 PVD
# NLP_7476_23.txt_1 pad_annotation 974 1002 ankle-brachial index is 0.41
# NLP_20794_49.txt_0 pad_annotation 213 216 pvd
# NLP_20794_49.txt_1 pad_annotation 488 491 pvd
# NLP_20794_49.txt_2 pad_annotation 1028 1066 ankle-brachial index
#      measures 1.6
# NLP_20794_49.txt_3 pad_annotation 1082 1109 ankle-brachial index could
# NLP_8992_24.txt_0 pad_annotation 670 704 ankle-
#      brachial index is 0.60
# NLP_8992_24.txt_1 pad_annotation 944 972 ankle-brachial index is 0.64
# NLP_4474_18.txt_0 pad_annotation 984 1008 Ankle brachial index is
# NLP_23643_59.txt_0 pad_annotation 585 613 Ankle-brachial index cannot
# NLP_23643_59.txt_1 pad_annotation 910 938 ankle-brachial index cannot
# NLP_1979_13.txt_0 pad_annotation 1095 1119 ankle/brachial index is
# NLP_1979_13.txt_1 pad_annotation 1444 1468 ankle/brachial index is
# NLP_13260_34.txt_0 pad_annotation 414 417 PVD
# NLP_13260_34.txt_1 pad_annotation 1110 1139 ankle-brachial index.  Pulse
# NLP_13260_34.txt_2 pad_annotation 1401 1429 Ankle brachial index is 0.49
# NLP_1369_8.txt_0 pad_annotation 1095 1128 ankle/brachial index
#      is 0.65
# NLP_1369_8.txt_1 pad_annotation 1367 1391 ankle/brachial index is
# NLP_2503_14.txt_0 pad_annotation 1738 1762 ankle brachial index is
# NLP_2503_14.txt_1 pad_annotation 1952 1980 ankle brachial index is 0.74
# NLP_846_3.txt_0 pad_annotation 188 191 PVD
# NLP_846_3.txt_1 pad_annotation 373 376 PVD
# NLP_846_3.txt_2 pad_annotation 460 463 PVD
# NLP_846_3.txt_3 pad_annotation 3088 3091 PVD
# NLP_846_3.txt_4 pad_annotation 2325 2349 ankle brachial index is
# NLP_846_3.txt_5 pad_annotation 2486 2498 ABI dropped
# NLP_846_3.txt_6 pad_annotation 2698 2726 ankle brachial index is 0.69
# NLP_846_3.txt_7 pad_annotation 3572 3654 ABI.
#
#
#
# NLP_6677_21.txt_0 pad_annotation 207 210 PVD
# NLP_6677_21.txt_1 pad_annotation 3156 3159 PVD
# NLP_6677_21.txt_2 pad_annotation 2609 2642 ankle brachial index of
#      0.57
# NLP_353_0.txt_0 pad_annotation 2655 2680 Ankle-brachial index was
# NLP_353_0.txt_1 pad_annotation 2720 2745 ankle-brachial index for
# NLP_16993_38.txt_0 pad_annotation 1073 1106 ankle brachial
#      index is 0.71
# NLP_16993_38.txt_1 pad_annotation 1368 1396 ankle brachial index is 0.78
# NLP_23097_56.txt_0 pad_annotation 1787 1815 ankle brachial index is 0.85
# NLP_23097_56.txt_1 pad_annotation 2058 2082 ankle brachial index is
# NLP_17758_41.txt_0 pad_annotation 1021 1045 ankle-brachial index is
# NLP_17758_41.txt_1 pad_annotation 1307 1335 ankle-brachial index is 0.92
# NLP_10594_29.txt_0 pad_annotation 209 216 ABI'S,
# NLP_10594_29.txt_1 pad_annotation 1360 1384 ankle brachial index is
# NLP_10594_29.txt_2 pad_annotation 1537 1548 ABI is 0.98
# NLP_25879_63.txt_0 pad_annotation 1419 1447 ankle brachial index is 0.71
# NLP_18600_43.txt_0 pad_annotation 419 422 pvd
# NLP_18600_43.txt_1 pad_annotation 1082 1114 ankle brachial
#      index could
# NLP_18600_43.txt_2 pad_annotation 1400 1427 ankle brachial index could
# NLP_12403_32.txt_0 pad_annotation 1020 1046 ankle/brachial index that
# NLP_12403_32.txt_1 pad_annotation 1361 1390 Ankle/brachial index is
#
# NLP_19468_48.txt_0 pad_annotation 1009 1037 Ankle brachial index is 0.70
# NLP_19468_48.txt_1 pad_annotation 1269 1297 ankle brachial index is 0.75
# NLP_23097_57.txt_0 pad_annotation 1787 1815 ankle brachial index is 0.85
# NLP_23097_57.txt_1 pad_annotation 2058 2082 ankle brachial index is
# NLP_1266_4.txt_0 pad_annotation 1062 1086 ankle brachial index is
# NLP_1266_4.txt_1 pad_annotation 1268 1297 ankle brachial index
#      on
# NLP_17411_40.txt_0 pad_annotation 1042 1070 ankle/brachial index is 0.88
# NLP_17411_40.txt_1 pad_annotation 1207 1235 ankle/brachial index is 0.87
# NLP_10083_27.txt_0 pad_annotation 217 220 PVD
# NLP_10083_27.txt_1 pad_annotation 778 781 PVD
# NLP_10083_27.txt_2 pad_annotation 1182 1209 ankle brachial index is 1.4
# NLP_12573_33.txt_0 pad_annotation 195 198 PAD
# NLP_12573_33.txt_1 pad_annotation 431 434 PVD
# NLP_12573_33.txt_2 pad_annotation 709 712 PAD
# NLP_12573_33.txt_3 pad_annotation 1097 1125 ankle brachial index is 0.73
# NLP_2832_16.txt_0 pad_annotation 545 551 ABI's
# NLP_2832_16.txt_1 pad_annotation 1026 1054 ankle brachial index is 0.93
# NLP_2832_16.txt_2 pad_annotation 1286 1319 Ankle
#      brachial index is 0.92
# NLP_24032_61.txt_0 pad_annotation 430 433 PVD
# NLP_24032_61.txt_1 pad_annotation 1639 1667 ankle-brachial index cannot
# NLP_24032_61.txt_2 pad_annotation 1964 1997 ankle-brachial index.
#      Pulse
# NLP_23643_58.txt_0 pad_annotation 1026 1050 ankle brachial index is
# NLP_14566_36.txt_0 pad_annotation 1151 1175 ankle-brachial index on
# NLP_14566_36.txt_1 pad_annotation 1413 1437 Ankle-brachial index is
# NLP_10594_28.txt_0 pad_annotation 209 216 ABI'S,
# NLP_10594_28.txt_1 pad_annotation 1360 1384 ankle brachial index is
# NLP_10594_28.txt_2 pad_annotation 1537 1548 ABI is 0.98
# NLP_18839_45.txt_0 pad_annotation 919 948 ankle-brachial
#      index is
# NLP_18839_45.txt_1 pad_annotation 1209 1236 ankle-brachial index is 0.8
# NLP_17758_42.txt_0 pad_annotation 1021 1045 ankle-brachial index is
# NLP_17758_42.txt_1 pad_annotation 1307 1335 ankle-brachial index is 0.92
# NLP_6677_20.txt_0 pad_annotation 207 210 PVD
# NLP_6677_20.txt_1 pad_annotation 3156 3159 PVD
# NLP_6677_20.txt_2 pad_annotation 2609 2642 ankle brachial index of
#      0.57
# NLP_1604_9.txt_0 pad_annotation 1142 1170 ankle-brachial indices, and
# NLP_1604_9.txt_1 pad_annotation 1320 1351 ankle-
#      brachial index of .
# NLP_1604_9.txt_2 pad_annotation 1511 1518 ABI of
# NLP_4550_19.txt_0 pad_annotation 1417 1441 Ankle/brachial index on
# NLP_1822_12.txt_0 pad_annotation 1081 1114 ankle brachial
#      index is 0.64
# NLP_24032_60.txt_0 pad_annotation 430 433 PVD
# NLP_24032_60.txt_1 pad_annotation 1639 1667 ankle-brachial index cannot
# NLP_24032_60.txt_2 pad_annotation 1964 1997 ankle-brachial index.
#      Pulse
# NLP_22368_55.txt_0 pad_annotation 364 367 pvd
# NLP_22368_55.txt_1 pad_annotation 969 1002 Ankle-brachial index
#      is 0.56
# NLP_22368_55.txt_2 pad_annotation 1296 1323 ankle-brachial index could
# NLP_22043_54.txt_0 pad_annotation 251 278 PERIPHERAL VASCULAR DISEASE
# NLP_22043_54.txt_1 pad_annotation 453 456 PVD
# NLP_22043_54.txt_2 pad_annotation 822 849 peripheral vascular disease
# NLP_22043_54.txt_3 pad_annotation 2251 2278 ankle brachial index is 0.5
# NLP_18839_44.txt_0 pad_annotation 900 929 ankle brachial index is
#
# NLP_18839_44.txt_1 pad_annotation 1126 1154 ankle brachial index is 0.76
# NLP_18839_44.txt_2 pad_annotation 1463 1497 ankle
#      brachial index changed
# NLP_18839_44.txt_3 pad_annotation 1581 1608 ankle brachial index could
# NLP_12403_31.txt_0 pad_annotation 692 716 ankle/brachial index is
# NLP_12403_31.txt_1 pad_annotation 1032 1056 ankle/brachial index is
# NLP_15011_37.txt_0 pad_annotation 1038 1065 ankle-brachial index could
# NLP_15011_37.txt_1 pad_annotation 1386 1413 ankle-brachial index could
# NLP_21380_52.txt_0 pad_annotation 426 429 pvd
# NLP_21380_52.txt_1 pad_annotation 916 946 ankle brachial index.  Pulsed
# NLP_21380_52.txt_2 pad_annotation 1187 1210 ankle brachial index 0.
# NLP_6809_22.txt_0 pad_annotation 457 460 PVD
# NLP_6809_22.txt_1 pad_annotation 163 169 ABI's
# NLP_6809_22.txt_2 pad_annotation 588 594 ABI's
# NLP_6809_22.txt_3 pad_annotation 1165 1193 ankle brachial index is 0.61
# NLP_6809_22.txt_4 pad_annotation 1439 1467 ankle brachial index is 0.83
# NLP_1371_7.txt_0 pad_annotation 357 360 PVD
# NLP_1371_7.txt_1 pad_annotation 761 788 peripheral vascular disease
# NLP_1371_7.txt_2 pad_annotation 1121 1151 ankle brachial index
#      was
# NLP_1371_7.txt_3 pad_annotation 1451 1476 ankle brachial index was
# NLP_18992_46.txt_0 pad_annotation 744 772 ankle brachial index is 0.97
# NLP_18992_46.txt_1 pad_annotation 1116 1140 Ankle brachial index is
# NLP_25742_62.txt_0 pad_annotation 994 1021 ankle brachial index could
# NLP_25742_62.txt_1 pad_annotation 1303 1331 Ankle brachial index is 0.96
# NLP_1266_5.txt_0 pad_annotation 241 268 PERIPHERAL VASCULAR DISEASE
# NLP_1266_5.txt_1 pad_annotation 1111 1139 ankle brachial index is 0.46
# NLP_25879_64.txt_0 pad_annotation 1419 1447 ankle brachial index is 0.71
# NLP_18992_47.txt_0 pad_annotation 744 772 ankle brachial index is 0.97
# NLP_18992_47.txt_1 pad_annotation 1116 1140 Ankle brachial index is
# NLP_9082_25.txt_0 pad_annotation 961 989 Ankle brachial index is 0.62
# NLP_9082_25.txt_1 pad_annotation 1231 1255 Ankle brachial index is
# NLP_846_2.txt_0 pad_annotation 188 191 PVD
# NLP_846_2.txt_1 pad_annotation 373 376 PVD
# NLP_846_2.txt_2 pad_annotation 460 463 PVD
# NLP_846_2.txt_3 pad_annotation 3088 3091 PVD
# NLP_846_2.txt_4 pad_annotation 2325 2349 ankle brachial index is
# NLP_846_2.txt_5 pad_annotation 2486 2498 ABI dropped
# NLP_846_2.txt_6 pad_annotation 2698 2726 ankle brachial index is 0.69
# NLP_846_2.txt_7 pad_annotation 3572 3654 ABI.
#
#
#
# NLP_2503_15.txt_0 pad_annotation 1738 1762 ankle brachial index is
# NLP_2503_15.txt_1 pad_annotation 1952 1980 ankle brachial index is 0.74
# NLP_26479_66.txt_0 pad_annotation 995 1023 ankle-brachial index is 0.60
# NLP_26479_66.txt_1 pad_annotation 1250 1278 ankle-brachial index is 0.60
# NLP_26136_65.txt_0 pad_annotation 1091 1123 ankle brachial index
#      could
# NLP_26136_65.txt_1 pad_annotation 1286 1313 ankle brachial index could
# NLP_1795_11.txt_0 pad_annotation 1018 1048 ankle
#      brachial index due
# NLP_9137_26.txt_0 pad_annotation 269 272 PVD
# NLP_9137_26.txt_1 pad_annotation 467 470 PVD
# NLP_9137_26.txt_2 pad_annotation 199 207 ABI FOR
# NLP_9137_26.txt_3 pad_annotation 560 568 ABI for
# NLP_9137_26.txt_4 pad_annotation 1109 1137 ankle brachial index is 0.90
# NLP_22043_53.txt_0 pad_annotation 251 278 PERIPHERAL VASCULAR DISEASE
# NLP_22043_53.txt_1 pad_annotation 453 456 PVD
# NLP_22043_53.txt_2 pad_annotation 822 849 peripheral vascular disease
# NLP_22043_53.txt_3 pad_annotation 2251 2278 ankle brachial index is 0.5
# NLP_3757_17.txt_0 pad_annotation 164 170 ABI S/
# NLP_3757_17.txt_1 pad_annotation 672 700 ankle/brachial index is 0.93
# NLP_3757_17.txt_2 pad_annotation 913 946 ankle/brachial
#      index is 0.43

# %%
tp_total = 0
fp_total = 0
fn_total = 0
tp_list_total = []
fp_list_total= []
fn_list_total = []
attributes_to_compare=[]
# To compare attributes, create a list of tuples for each pair to compare:
# attributes_to_compare.append[(A1_type, A1_att_name, A1_att_value),(A2_type, A2_att_name, A2_att_value)]
attributes_to_compare.append([('PAD', 'Negation', 'Negated'),('pad_annotation', 'Negation', 'Negated')])

for doc_id in test_docs.keys():
    tp, fp, fn, tp_list, fp_list, fn_list = (test_docs.get(doc_id)).\
    compare_types_by_span_and_attributes('PAD','pad_annotation', attributes_to_compare , False)
    tp_total = tp_total + tp
    fp_total = fp_total + fp
    fn_total = fn_total + fn
    tp_list_total.extend(tp_list)
    fp_list_total.extend(fp_list)
    fn_list_total.extend(fn_list)

print('TP =',tp_total, 'FP =',fp_total, 'FN =',fn_total)

if tp_total > 0 :
    precision = tp_total / (tp_total + fp_total)
    print('Precision=',round(precision,3))

if tp_total > 0 :
    recall = tp_total / (tp_total + fn_total)
    print('Recall=',round(recall,3))

#for a in tp_list_total:
#    print(a[0].toString(),'||', a[1].toString())
for a in fp_list_total:
    print(a.toString())
for a in fn_list_total:
    print(a.toString())
# Out:
# TP = 0 FP = 177 FN = 0
# NLP_17411_39.txt_0 pad_annotation 1073 1101 ankle-brachial index is 0.78
# NLP_17411_39.txt_1 pad_annotation 1501 1529 ankle-brachial index is 0.87
# NLP_1604_10.txt_0 pad_annotation 1142 1170 ankle-brachial indices, and
# NLP_1604_10.txt_1 pad_annotation 1320 1351 ankle-
#      brachial index of .
# NLP_1604_10.txt_2 pad_annotation 1511 1518 ABI of
# NLP_12272_30.txt_0 pad_annotation 176 182 ABI B/
# NLP_12272_30.txt_1 pad_annotation 557 563 ABI B/
# NLP_12272_30.txt_2 pad_annotation 1074 1106 ankle brachial
#      index could
# NLP_12272_30.txt_3 pad_annotation 1412 1440 Ankle brachial index is 0.79
# NLP_13625_35.txt_0 pad_annotation 440 443 PVD
# NLP_13625_35.txt_1 pad_annotation 1007 1031 ankle/brachial index is
# NLP_13625_35.txt_2 pad_annotation 1229 1253 ankle/brachial index is
# NLP_732_1.txt_0 pad_annotation 419 422 PVD
# NLP_732_1.txt_1 pad_annotation 986 1015 ankle-brachial index
#      is
# NLP_21380_51.txt_0 pad_annotation 2116 2143 Peripheral vascular disease
# NLP_21380_51.txt_1 pad_annotation 8924 8951 Peripheral vascular disease
# NLP_21380_51.txt_2 pad_annotation 10287 10314 peripheral vascular
# disease
# NLP_21380_51.txt_3 pad_annotation 9019 9047 ankle brachial indexes
# were
# NLP_21380_51.txt_4 pad_annotation 9222 9246 ankle brachial index on
# NLP_21223_50.txt_0 pad_annotation 1665 1693 ankle-brachial indices were
# NLP_21223_50.txt_1 pad_annotation 1755 1784 ankle-brachial index was 0.36
# NLP_1266_6.txt_0 pad_annotation 1513 1542 ankle-brachial index was 0.52
# NLP_7476_23.txt_0 pad_annotation 352 355 PVD
# NLP_7476_23.txt_1 pad_annotation 974 1002 ankle-brachial index is 0.41
# NLP_20794_49.txt_0 pad_annotation 213 216 pvd
# NLP_20794_49.txt_1 pad_annotation 488 491 pvd
# NLP_20794_49.txt_2 pad_annotation 1028 1066 ankle-brachial index
#      measures 1.6
# NLP_20794_49.txt_3 pad_annotation 1082 1109 ankle-brachial index could
# NLP_8992_24.txt_0 pad_annotation 670 704 ankle-
#      brachial index is 0.60
# NLP_8992_24.txt_1 pad_annotation 944 972 ankle-brachial index is 0.64
# NLP_4474_18.txt_0 pad_annotation 984 1008 Ankle brachial index is
# NLP_23643_59.txt_0 pad_annotation 585 613 Ankle-brachial index cannot
# NLP_23643_59.txt_1 pad_annotation 910 938 ankle-brachial index cannot
# NLP_1979_13.txt_0 pad_annotation 1095 1119 ankle/brachial index is
# NLP_1979_13.txt_1 pad_annotation 1444 1468 ankle/brachial index is
# NLP_13260_34.txt_0 pad_annotation 414 417 PVD
# NLP_13260_34.txt_1 pad_annotation 1110 1139 ankle-brachial index.  Pulse
# NLP_13260_34.txt_2 pad_annotation 1401 1429 Ankle brachial index is 0.49
# NLP_1369_8.txt_0 pad_annotation 1095 1128 ankle/brachial index
#      is 0.65
# NLP_1369_8.txt_1 pad_annotation 1367 1391 ankle/brachial index is
# NLP_2503_14.txt_0 pad_annotation 1738 1762 ankle brachial index is
# NLP_2503_14.txt_1 pad_annotation 1952 1980 ankle brachial index is 0.74
# NLP_846_3.txt_0 pad_annotation 188 191 PVD
# NLP_846_3.txt_1 pad_annotation 373 376 PVD
# NLP_846_3.txt_2 pad_annotation 460 463 PVD
# NLP_846_3.txt_3 pad_annotation 3088 3091 PVD
# NLP_846_3.txt_4 pad_annotation 2325 2349 ankle brachial index is
# NLP_846_3.txt_5 pad_annotation 2486 2498 ABI dropped
# NLP_846_3.txt_6 pad_annotation 2698 2726 ankle brachial index is 0.69
# NLP_846_3.txt_7 pad_annotation 3572 3654 ABI.
#
#
#
# NLP_6677_21.txt_0 pad_annotation 207 210 PVD
# NLP_6677_21.txt_1 pad_annotation 3156 3159 PVD
# NLP_6677_21.txt_2 pad_annotation 2609 2642 ankle brachial index of
#      0.57
# NLP_353_0.txt_0 pad_annotation 2655 2680 Ankle-brachial index was
# NLP_353_0.txt_1 pad_annotation 2720 2745 ankle-brachial index for
# NLP_16993_38.txt_0 pad_annotation 1073 1106 ankle brachial
#      index is 0.71
# NLP_16993_38.txt_1 pad_annotation 1368 1396 ankle brachial index is 0.78
# NLP_23097_56.txt_0 pad_annotation 1787 1815 ankle brachial index is 0.85
# NLP_23097_56.txt_1 pad_annotation 2058 2082 ankle brachial index is
# NLP_17758_41.txt_0 pad_annotation 1021 1045 ankle-brachial index is
# NLP_17758_41.txt_1 pad_annotation 1307 1335 ankle-brachial index is 0.92
# NLP_10594_29.txt_0 pad_annotation 209 216 ABI'S,
# NLP_10594_29.txt_1 pad_annotation 1360 1384 ankle brachial index is
# NLP_10594_29.txt_2 pad_annotation 1537 1548 ABI is 0.98
# NLP_25879_63.txt_0 pad_annotation 1419 1447 ankle brachial index is 0.71
# NLP_18600_43.txt_0 pad_annotation 419 422 pvd
# NLP_18600_43.txt_1 pad_annotation 1082 1114 ankle brachial
#      index could
# NLP_18600_43.txt_2 pad_annotation 1400 1427 ankle brachial index could
# NLP_12403_32.txt_0 pad_annotation 1020 1046 ankle/brachial index that
# NLP_12403_32.txt_1 pad_annotation 1361 1390 Ankle/brachial index is
#
# NLP_19468_48.txt_0 pad_annotation 1009 1037 Ankle brachial index is 0.70
# NLP_19468_48.txt_1 pad_annotation 1269 1297 ankle brachial index is 0.75
# NLP_23097_57.txt_0 pad_annotation 1787 1815 ankle brachial index is 0.85
# NLP_23097_57.txt_1 pad_annotation 2058 2082 ankle brachial index is
# NLP_1266_4.txt_0 pad_annotation 1062 1086 ankle brachial index is
# NLP_1266_4.txt_1 pad_annotation 1268 1297 ankle brachial index
#      on
# NLP_17411_40.txt_0 pad_annotation 1042 1070 ankle/brachial index is 0.88
# NLP_17411_40.txt_1 pad_annotation 1207 1235 ankle/brachial index is 0.87
# NLP_10083_27.txt_0 pad_annotation 217 220 PVD
# NLP_10083_27.txt_1 pad_annotation 778 781 PVD
# NLP_10083_27.txt_2 pad_annotation 1182 1209 ankle brachial index is 1.4
# NLP_12573_33.txt_0 pad_annotation 195 198 PAD
# NLP_12573_33.txt_1 pad_annotation 431 434 PVD
# NLP_12573_33.txt_2 pad_annotation 709 712 PAD
# NLP_12573_33.txt_3 pad_annotation 1097 1125 ankle brachial index is 0.73
# NLP_2832_16.txt_0 pad_annotation 545 551 ABI's
# NLP_2832_16.txt_1 pad_annotation 1026 1054 ankle brachial index is 0.93
# NLP_2832_16.txt_2 pad_annotation 1286 1319 Ankle
#      brachial index is 0.92
# NLP_24032_61.txt_0 pad_annotation 430 433 PVD
# NLP_24032_61.txt_1 pad_annotation 1639 1667 ankle-brachial index cannot
# NLP_24032_61.txt_2 pad_annotation 1964 1997 ankle-brachial index.
#      Pulse
# NLP_23643_58.txt_0 pad_annotation 1026 1050 ankle brachial index is
# NLP_14566_36.txt_0 pad_annotation 1151 1175 ankle-brachial index on
# NLP_14566_36.txt_1 pad_annotation 1413 1437 Ankle-brachial index is
# NLP_10594_28.txt_0 pad_annotation 209 216 ABI'S,
# NLP_10594_28.txt_1 pad_annotation 1360 1384 ankle brachial index is
# NLP_10594_28.txt_2 pad_annotation 1537 1548 ABI is 0.98
# NLP_18839_45.txt_0 pad_annotation 919 948 ankle-brachial
#      index is
# NLP_18839_45.txt_1 pad_annotation 1209 1236 ankle-brachial index is 0.8
# NLP_17758_42.txt_0 pad_annotation 1021 1045 ankle-brachial index is
# NLP_17758_42.txt_1 pad_annotation 1307 1335 ankle-brachial index is 0.92
# NLP_6677_20.txt_0 pad_annotation 207 210 PVD
# NLP_6677_20.txt_1 pad_annotation 3156 3159 PVD
# NLP_6677_20.txt_2 pad_annotation 2609 2642 ankle brachial index of
#      0.57
# NLP_1604_9.txt_0 pad_annotation 1142 1170 ankle-brachial indices, and
# NLP_1604_9.txt_1 pad_annotation 1320 1351 ankle-
#      brachial index of .
# NLP_1604_9.txt_2 pad_annotation 1511 1518 ABI of
# NLP_4550_19.txt_0 pad_annotation 1417 1441 Ankle/brachial index on
# NLP_1822_12.txt_0 pad_annotation 1081 1114 ankle brachial
#      index is 0.64
# NLP_24032_60.txt_0 pad_annotation 430 433 PVD
# NLP_24032_60.txt_1 pad_annotation 1639 1667 ankle-brachial index cannot
# NLP_24032_60.txt_2 pad_annotation 1964 1997 ankle-brachial index.
#      Pulse
# NLP_22368_55.txt_0 pad_annotation 364 367 pvd
# NLP_22368_55.txt_1 pad_annotation 969 1002 Ankle-brachial index
#      is 0.56
# NLP_22368_55.txt_2 pad_annotation 1296 1323 ankle-brachial index could
# NLP_22043_54.txt_0 pad_annotation 251 278 PERIPHERAL VASCULAR DISEASE
# NLP_22043_54.txt_1 pad_annotation 453 456 PVD
# NLP_22043_54.txt_2 pad_annotation 822 849 peripheral vascular disease
# NLP_22043_54.txt_3 pad_annotation 2251 2278 ankle brachial index is 0.5
# NLP_18839_44.txt_0 pad_annotation 900 929 ankle brachial index is
#
# NLP_18839_44.txt_1 pad_annotation 1126 1154 ankle brachial index is 0.76
# NLP_18839_44.txt_2 pad_annotation 1463 1497 ankle
#      brachial index changed
# NLP_18839_44.txt_3 pad_annotation 1581 1608 ankle brachial index could
# NLP_12403_31.txt_0 pad_annotation 692 716 ankle/brachial index is
# NLP_12403_31.txt_1 pad_annotation 1032 1056 ankle/brachial index is
# NLP_15011_37.txt_0 pad_annotation 1038 1065 ankle-brachial index could
# NLP_15011_37.txt_1 pad_annotation 1386 1413 ankle-brachial index could
# NLP_21380_52.txt_0 pad_annotation 426 429 pvd
# NLP_21380_52.txt_1 pad_annotation 916 946 ankle brachial index.  Pulsed
# NLP_21380_52.txt_2 pad_annotation 1187 1210 ankle brachial index 0.
# NLP_6809_22.txt_0 pad_annotation 457 460 PVD
# NLP_6809_22.txt_1 pad_annotation 163 169 ABI's
# NLP_6809_22.txt_2 pad_annotation 588 594 ABI's
# NLP_6809_22.txt_3 pad_annotation 1165 1193 ankle brachial index is 0.61
# NLP_6809_22.txt_4 pad_annotation 1439 1467 ankle brachial index is 0.83
# NLP_1371_7.txt_0 pad_annotation 357 360 PVD
# NLP_1371_7.txt_1 pad_annotation 761 788 peripheral vascular disease
# NLP_1371_7.txt_2 pad_annotation 1121 1151 ankle brachial index
#      was
# NLP_1371_7.txt_3 pad_annotation 1451 1476 ankle brachial index was
# NLP_18992_46.txt_0 pad_annotation 744 772 ankle brachial index is 0.97
# NLP_18992_46.txt_1 pad_annotation 1116 1140 Ankle brachial index is
# NLP_25742_62.txt_0 pad_annotation 994 1021 ankle brachial index could
# NLP_25742_62.txt_1 pad_annotation 1303 1331 Ankle brachial index is 0.96
# NLP_1266_5.txt_0 pad_annotation 241 268 PERIPHERAL VASCULAR DISEASE
# NLP_1266_5.txt_1 pad_annotation 1111 1139 ankle brachial index is 0.46
# NLP_25879_64.txt_0 pad_annotation 1419 1447 ankle brachial index is 0.71
# NLP_18992_47.txt_0 pad_annotation 744 772 ankle brachial index is 0.97
# NLP_18992_47.txt_1 pad_annotation 1116 1140 Ankle brachial index is
# NLP_9082_25.txt_0 pad_annotation 961 989 Ankle brachial index is 0.62
# NLP_9082_25.txt_1 pad_annotation 1231 1255 Ankle brachial index is
# NLP_846_2.txt_0 pad_annotation 188 191 PVD
# NLP_846_2.txt_1 pad_annotation 373 376 PVD
# NLP_846_2.txt_2 pad_annotation 460 463 PVD
# NLP_846_2.txt_3 pad_annotation 3088 3091 PVD
# NLP_846_2.txt_4 pad_annotation 2325 2349 ankle brachial index is
# NLP_846_2.txt_5 pad_annotation 2486 2498 ABI dropped
# NLP_846_2.txt_6 pad_annotation 2698 2726 ankle brachial index is 0.69
# NLP_846_2.txt_7 pad_annotation 3572 3654 ABI.
#
#
#
# NLP_2503_15.txt_0 pad_annotation 1738 1762 ankle brachial index is
# NLP_2503_15.txt_1 pad_annotation 1952 1980 ankle brachial index is 0.74
# NLP_26479_66.txt_0 pad_annotation 995 1023 ankle-brachial index is 0.60
# NLP_26479_66.txt_1 pad_annotation 1250 1278 ankle-brachial index is 0.60
# NLP_26136_65.txt_0 pad_annotation 1091 1123 ankle brachial index
#      could
# NLP_26136_65.txt_1 pad_annotation 1286 1313 ankle brachial index could
# NLP_1795_11.txt_0 pad_annotation 1018 1048 ankle
#      brachial index due
# NLP_9137_26.txt_0 pad_annotation 269 272 PVD
# NLP_9137_26.txt_1 pad_annotation 467 470 PVD
# NLP_9137_26.txt_2 pad_annotation 199 207 ABI FOR
# NLP_9137_26.txt_3 pad_annotation 560 568 ABI for
# NLP_9137_26.txt_4 pad_annotation 1109 1137 ankle brachial index is 0.90
# NLP_22043_53.txt_0 pad_annotation 251 278 PERIPHERAL VASCULAR DISEASE
# NLP_22043_53.txt_1 pad_annotation 453 456 PVD
# NLP_22043_53.txt_2 pad_annotation 822 849 peripheral vascular disease
# NLP_22043_53.txt_3 pad_annotation 2251 2278 ankle brachial index is 0.5
# NLP_3757_17.txt_0 pad_annotation 164 170 ABI S/
# NLP_3757_17.txt_1 pad_annotation 672 700 ankle/brachial index is 0.93
# NLP_3757_17.txt_2 pad_annotation 913 946 ankle/brachial
#      index is 0.43

# %%
import pymysql
import pandas as pd
import getpass
import re

conn = pymysql.connect(host="mysql",
                       port=3306,user="jovyan",
                       passwd=getpass.getpass("Enter MySQL passwd for jovyan"),db='mimic2')
cursor = conn.cursor()

# %%
pad_data = pd.read_sql("""SELECT subject_id, 
                      category, 
                      text FROM noteevents limit 100000 """,conn)

# %%
final_nlp_system = PadClassificationSystem()

# %%
output = []
counter = 0
for index , row in pad_data.sample(10000).iterrows():    
    doc = Document(document_id=str(row.subject_id) + '_' + str(index), text=row.text)
    final_nlp_system.process(doc)
    if(len(doc.annotations) > 0):
        i = 1
        for a in doc.annotations:
            if( a.type == 'pad_annotation'):
                neg_flag = 0
                # Switch the flag to 1 when the mention is negated
                if('definite_negated_existence' in a.attributes):
                    neg_flag=1
                ### Each row in the dictionary
                record_id  = str(row.subject_id) + '_' + str(index)+'_'+str(i)
                subject_id =  row.subject_id
                note_id = str(row.subject_id) + '_' + str(index)
                annotation_type = a.type
                snippet = doc.text[int(a.start_index): int(a.end_index)]
                out_list = [record_id, subject_id, note_id, annotation_type, \
                            a.start_index, a.end_index, \
                            snippet, neg_flag]
                output.append(out_list)
                i=i+1
                counter=counter+1
                # Print . after 10 identified records
                if counter%10 == 0:
                    print('.', end='')
        else:
            continue
        break

# %%
columns=['record_id','subject_id', 'note_id', 'annotation_type', 'span_start', 'span_end', 'PAD_snippet', 'neg_flag']
result_data_frame = (pd.DataFrame(output, columns=columns))

result_data_frame.describe()
result_data_frame

# %%
result_data_frame.to_csv('out_table.csv', index=False)
print('Done')
